# %% [markdown]
# <a href="https://colab.research.google.com/github/yenlung/Python-Book/blob/master/%E5%86%92%E9%9A%AA38_%E7%94%A8%20Groupby%20%E6%89%BE%E5%88%B0%E7%BE%8E%E5%9C%8B%E6%9C%80%E5%B8%B8%E7%9B%AE%E6%93%8A%20UFO%20%E7%9A%84%E5%B7%9E.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# 我們現在想知道美國哪一州最常看到 UFO，然後我們就去那一州碰碰運氣，看能不能看到 UFO。
#
# 這個資料集是由我們非常推薦的 `pandas` 介紹系列影片, 請大家想更深入瞭解 `pandas` 一定要參考!
#
# [Pandas 介紹系列影片](https://github.com/justmarkham/pandas-videos)

# %% [markdown]
# 讀進美國 UFO 的資料。

# %%
df = pd.read_csv("http://bit.ly/uforeports")

# %% [markdown]
# 看資料前五筆。

# %%
df.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %% [markdown]
# 用 groupby 以州來分組，計算每一欄出現幾筆資料。

# %%
df_state = df.groupby("State").count()

# %% [markdown]
# Time 這欄表示不同州出現 UFO 的次數。

# %%
df_state.head()
# Out:
#        City  Colors Reported  Shape Reported  Time
# State
# AK      116               25              99   116
# AL      193               21             173   193
# AR      206               26             186   206
# AZ      736              145             644   738
# CA     2525              457            2148  2529

# %% [markdown]
# 我們想知道最常出現 UFO 的州，所以要根據 Time 來排序。

# %%
df_state.sort_values(by="Time", ascending = False)
# Out:
#        City  Colors Reported  Shape Reported  Time
# State
# CA     2525              457            2148  2529
# WA     1320              269             925  1322
# TX     1025              138             923  1027
# NY      913              123             823   914
# FL      835              120             727   837
# AZ      736              145             644   738
# OH      665               93             605   667
# IL      612              112             540   613
# PA      598               97             519   598
# MI      590               78             504   591
# OR      534               89             414   534
# MO      448               86             386   448
# NJ      370               51             326   370
# CO      367               60             322   367
# WI      357               63             312   357
# NC      356               55             325   356
# IN      326               49             296   326
# GA      325               44             294   325
# MA      322               50             276   322
# VA      299               51             253   299
# TN      286               41             247   286
# NV      281               45             236   284
# MN      254               40             223   254
# KY      244               34             220   244
# NM      241               28             193   241
# CT      225               25             188   225
# MD      215               34             185   215
# AR      206               26             186   206
# OK      193               22             167   193
# AL      193               21             173   193
# UT      193               36             172   193
# ME      181               28             153   181
# KS      176               33             144   176
# LA      172               16             148   174
# SC      166               22             148   166
# IA      162               28             142   162
# MT      143               22             114   144
# MS      139               17             126   139
# WV      131               13             112   132
# ID      130               12             109   130
# NH      124               20             113   125
# AK      116               25              99   116
# NE      101                7              89   101
# HI       85               16              74    85
# WY       69                6              57    69
# RI       67                8              62    67
# SD       57               10              39    57
# ND       51                5              43    51
# VT       44                6              34    44
# DE       43                5              38    43
# Fl        4                1               0     4
# Ca        1                0               1     1

# %% [markdown]
# inplace = True 指令讓你可以直接修改原本的 DataDrame。

# %%
df_state.sort_values(by="Time", ascending=False, inplace=True)

# %% [markdown]
# 得到我們要的結果了！

# %%
df_state.head(10)
# Out:
#        City  Colors Reported  Shape Reported  Time
# State
# CA     2525              457            2148  2529
# WA     1320              269             925  1322
# TX     1025              138             923  1027
# NY      913              123             823   914
# FL      835              120             727   837
# AZ      736              145             644   738
# OH      665               93             605   667
# IL      612              112             540   613
# PA      598               97             519   598
# MI      590               78             504   591

# %%
df_state[:10]
# Out:
#        City  Colors Reported  Shape Reported  Time
# State
# CA     2525              457            2148  2529
# WA     1320              269             925  1322
# TX     1025              138             923  1027
# NY      913              123             823   914
# FL      835              120             727   837
# AZ      736              145             644   738
# OH      665               93             605   667
# IL      612              112             540   613
# PA      598               97             519   598
# MI      590               78             504   591

# %% [markdown]
# 畫個圖更清楚，用長條圖看出最常出現 UFO 的 10 個州。

# %%
df_state[:10].Time.plot(kind='bar')
